# %%
spam = [1, 2, 3]

# %%
def double(ll):
    return [_*2 for _ in ll]

# %%
class Foo:
    def __init__(self, name):
        self.name = name
    
    def __repr__(self):
        return f"<Foo value='{self.name}'>"
    
    def say_hello(self):
        return f"Hello {self.name}!"
